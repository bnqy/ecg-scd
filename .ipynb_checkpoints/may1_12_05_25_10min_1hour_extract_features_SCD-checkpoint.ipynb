# %%
import wfdb
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.signal import medfilt
import pywt
from ecgdetectors import Detectors
from scipy.signal import resample_poly
import csv

# %% [markdown]
# # SCD DB

# %%
scd_data = {
     './data/scddb/30': '07:54:33',
     './data/scddb/31': '13:42:24',
     './data/scddb/32': '16:45:18',
     './data/scddb/33': '04:46:19',
     './data/scddb/34': '06:35:44',
     './data/scddb/35': '24:34:56',
     './data/scddb/36': '18:59:01',
     './data/scddb/37': '01:31:13',
     './data/scddb/38': '08:01:54',
     './data/scddb/39': '04:37:51',
     #'./data/scddb/40': '00:00:00', # paced, no VF
     #'./data/scddb/41': '02:59:24', # not working properly
     #'./data/scddb/42': '00:00:00', # no VF
     './data/scddb/43': '15:37:11',
     './data/scddb/44': '19:38:45',
     './data/scddb/45': '18:09:17',
     './data/scddb/46': '03:41:47',
     './data/scddb/47': '06:13:01',
     './data/scddb/48': '02:29:40',
     #'./data/scddb/49': '00:00:00', # paced, no VF
     './data/scddb/50': '11:45:43',
     './data/scddb/51': '22:58:23',
     './data/scddb/52': '02:32:40'
}

# %%
# H:M:S to seconds
def hms_to_seconds(hms):
    h, m, s = hms.split(':')
    return int(h)*3600 + int(m)*60 + int(s)

# %%
def extract_before_onset_VF(vfon_dict, minutes_before=60, fs=250):
    ecg_data_map = {} 

    for record_path, vf_onset_str in vfon_dict.items():
        # record_path might be '.data/scddb/30'
        record_dir, record_name = os.path.split(record_path)

        # 2) Convert dictionary's VF onset to seconds
        vf_onset_original_sec = hms_to_seconds(vf_onset_str)

        vfon_onset_original_sample = vf_onset_original_sec * fs

        seg_len_samples = int(minutes_before * 60 * fs)

        start_sample = vfon_onset_original_sample - seg_len_samples

         # read .dat between those sample indices
        try:
            #record_dat_path = os.path.join(record_dir, record_name)  # base path
            record_path_dat = os.path.join(record_dir, record_name)
            segment = wfdb.rdrecord(record_path_dat, sampfrom=start_sample, sampto=vfon_onset_original_sample)
            
        except Exception as e:
            print(f"[ERROR] Failed to read record {record_dat_path}: {e}")
            continue

        # Retrieve the raw signal data as a NumPy array
        if segment.p_signal is not None:
            arr = segment.p_signal[:,0]
            ecg_data_map[record_name] = arr
            print(f"[OK] Extracted 60-min for {record_name}: shape={arr.shape}")
        else:
            print(f"[WARNING] No p_signal found for {record_name}")

    return ecg_data_map

# %%
def segment_ecg(ecg_segment, segment_duration_sec=600, fs=250):
    samples_per_segment = segment_duration_sec * fs
    segments = np.array_split(ecg_segment, len(ecg_segment) // samples_per_segment)
    return segments

# %%
def resample_ecg(ecg_signal, orig_fs, target_fs):
    """
    Resample ECG signal from orig_fs to target_fs using polyphase filtering.
    ecg_signal: 1D (or 2D) numpy array (samples x channels)
    """
    # For example, if orig_fs=250, target_fs=128:
    # up = 128, down = 250
    up = target_fs
    down = orig_fs

    if ecg_signal.ndim == 1:
        ecg_resampled = resample_poly(ecg_signal, up, down)
    else:
        # If multi-channel, resample each column
        ecg_resampled = np.array([
            resample_poly(ecg_signal[:, ch], up, down) 
            for ch in range(ecg_signal.shape[1])
        ]).T

    return ecg_resampled

# %%
def denoise_signal(X, dwt_transform, dlevels, cutoff_low, cutoff_high):
    coeffs = pywt.wavedec(X, dwt_transform, level=dlevels)   # wavelet transform 'bior4.4'
    # scale 0 to cutoff_low 
    for ca in range(0,cutoff_low):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    # scale cutoff_high to end
    for ca in range(cutoff_high, len(coeffs)):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    Y = pywt.waverec(coeffs, dwt_transform) # inverse wavelet transform
    return Y

# %%
def r_peak_finder(ecg_sig):
    BASIC_SRATE = 128
    signal_pad_samples = 10
    signal_pad = np.zeros(signal_pad_samples)  # Pad to help detect early peaks
    scd_30_denoised_ = ...  # Your denoised 30-min ECG segment
    
    # Initialize the detectors at the given sampling rate
    detector_obj = Detectors(BASIC_SRATE)
    
    # Dictionary of detector functions
    detectors = {
        'pan_tompkins_detector': detector_obj.pan_tompkins_detector,
        'hamilton_detector': detector_obj.hamilton_detector,
        'christov_detector': detector_obj.christov_detector,
        'engzee_detector': detector_obj.engzee_detector,
        'swt_detector': detector_obj.swt_detector,
        'two_average_detector': detector_obj.two_average_detector,
    }
    
    r_peaks = np.array(detector_obj.swt_detector(np.hstack((signal_pad, ecg_sig)) )) - signal_pad_samples
    return r_peaks

# %%
def compute_hrv_features(r_peaks, fs=128):
    """
    Time-domain HRV features from R-peaks.
    Returns a dict with:
      MeanRR, RMSDD, pNN50, SDRR, CVRR, NN50, MinRR, MaxRR
    """
    features = {
        'MeanRR': 0.0,
        'RMSDD': 0.0,
        'MADRR': 0.0,
        'MCVNN': 0.0,
        'pNN20': 0.0,
        'pNN50': 0.0,
        'SDRR': 0.0,
        'CVRR': 0.0,
        'NN20': 0,
        'NN50': 0,
        'MinRR': 0.0,
        'MaxRR': 0.0
    }

    rr_samples = np.diff(r_peaks)
    rr_ms = (rr_samples / fs) * 1000.0  # convert to ms

    mean_rr = np.mean(rr_ms)
    sdrr = np.std(rr_ms, ddof=1) if len(rr_ms) > 1 else 0.0
    min_rr = np.min(rr_ms)
    max_rr = np.max(rr_ms)

    rr_diffs = np.diff(rr_ms)
    rmssd = np.sqrt(np.mean(rr_diffs**2)) if len(rr_diffs) > 0 else 0.0
    nn50 = np.sum(np.abs(rr_diffs) > 50)
    pnn50 = (nn50 / len(rr_diffs)) * 100 if len(rr_diffs) > 0 else 0.0
    nn20 = np.sum(np.abs(rr_diffs) > 20)
    pnn20 = (nn20 / len(rr_diffs)) * 100 if len(rr_diffs) > 0 else 0.0
    cvrr = (sdrr / mean_rr * 100.0) if mean_rr else 0.0
    madrr = np.median(np.abs(rr_ms - np.median(rr_ms)))
    mcvnn = np.abs(rr_samples).mean()

    features['MeanRR'] = mean_rr / 1000.0
    features['RMSDD'] = rmssd / 1000.0
    # new 
    features['MADRR'] = madrr / 1000.0
    features['MCVNN'] = mcvnn / 1000.0 
    features['pNN20'] = pnn20 / 1000.0
    
    
    features['pNN50'] = pnn50 / 1000.0
    features['SDRR'] = sdrr / 1000.0
    features['CVRR'] = cvrr / 1000.0 
    # new
    features['NN20'] = nn20 / 1000.0
    
    features['NN50'] = nn50 / 1000.0
    features['MinRR'] = min_rr / 1000.0 
    features['MaxRR'] = max_rr / 1000.0
    
    return features

# %%
label_map = ["First", "Second", "Third", "Fourth", "Fifth", "Sixth"]

def save_hrv_to_csv(features_dict, csv_path):
    """
    Save a single row of features_dict into a CSV at csv_path.
    Overwrites if file exists.
    Columns: [MeanRR, RMSDD, MADRR, MCVNN, pNN20, pNN50, SDRR, CVRR, NN20, NN50, MinRR, MaxRR]
    """
    columns = ["MeanRR", "RMSDD", "MADRR", "MCVNN", "pNN20", "pNN50", "SDRR", "CVRR", "NN20", "NN50", "MinRR", "MaxRR"]
    with open(csv_path, mode='w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=columns)
        writer.writeheader()
        writer.writerow({col: features_dict[col] for col in columns})
    print(f"  -> Saved HRV features to {csv_path}")

# %%
onsetVF_60min_scd = extract_before_onset_VF(scd_data, minutes_before=60, fs=250)
# Out:
# [OK] Extracted 60-min for 30: shape=(900000,)
# [OK] Extracted 60-min for 31: shape=(900000,)
# [OK] Extracted 60-min for 32: shape=(900000,)
# [OK] Extracted 60-min for 33: shape=(900000,)
# [OK] Extracted 60-min for 34: shape=(900000,)
# [OK] Extracted 60-min for 35: shape=(900000,)
# [OK] Extracted 60-min for 36: shape=(900000,)
# [OK] Extracted 60-min for 37: shape=(900000,)
# [OK] Extracted 60-min for 38: shape=(900000,)
# [OK] Extracted 60-min for 39: shape=(900000,)
# [OK] Extracted 60-min for 41: shape=(900000,)
# [OK] Extracted 60-min for 43: shape=(900000,)
# [OK] Extracted 60-min for 44: shape=(900000,)
# [OK] Extracted 60-min for 45: shape=(900000,)
# [OK] Extracted 60-min for 46: shape=(900000,)
# [OK] Extracted 60-min for 47: shape=(900000,)
# [OK] Extracted 60-min for 48: shape=(900000,)
# [OK] Extracted 60-min for 50: shape=(900000,)
# [OK] Extracted 60-min for 51: shape=(900000,)
# [OK] Extracted 60-min for 52: shape=(900000,)

# %%
len(onsetVF_60min_scd)
# Out:
# 20

# %%
scd_segments = {}
for key, value in onsetVF_60min_scd.items():
    scd_segments[key] = segment_ecg(value)

# %%
scd_segments['30']
# Out:
# [array([-0.2675 , -0.26625, -0.2625 , ...,  0.285  ,  0.395  ,  0.49875]),
#  array([ 0.61125,  0.665  ,  0.69875, ..., -0.10125, -0.0975 , -0.1    ]),
#  array([-0.1025 , -0.10375, -0.1025 , ...,  0.09125,  0.1    ,  0.10375]),
#  array([ 0.11   ,  0.11875,  0.13   , ..., -0.21625, -0.2175 , -0.22375]),
#  array([-0.2275 , -0.23125, -0.23625, ..., -0.005  ,  0.02   ,  0.0525 ]),
#  array([ 0.11375,  0.1975 ,  0.315  , ..., -0.03625, -0.03875, -0.0425 ])]

# %%
output_dir_scd = "SCD_Features_CSV_1h_10min_segments"
os.makedirs(output_dir_scd, exist_ok=True)

# %%
g = {'41': [np.array([-0.2675]),
                  np.array([-0.2675]),
           np.array([-0.2675]),
           np.array([-0.2675]),
           np.array([-0.2675]),
           np.array([-0.2675])]}
f = {'41': [np.array([-0.2675]),
                  np.array([-0.2675]),
           np.array([-0.2675]),
           np.array([-0.2675]),
           np.array([-0.2675]),
           np.array([-0.2675])]}
for subj_id, seg_list in scd_segments.items():
    print(f"\nProcessing SCD subject {subj_id}...")
    # seg_list[0] = earliest, seg_list[5] = last
    # We want to label them in REVERSE order:
    #   i=0 => seg_list[5], name: "First 5 mins before SCD"
    #   i=1 => seg_list[4], name: "Second 5 mins before SCD"
    #   ...
    #   i=5 => seg_list[0], name: "Sixth 5 mins before SCD"
    for i in range(6):
        segment_idx = 5 - i  # reversed index
        segment_label = f"SCD_{subj_id}_{label_map[i]}_10_mins_before_SCD"  # e.g. "First_5_mins_before_SCD"
        ecg_signal = seg_list[segment_idx]


        downsampled = resample_ecg(ecg_signal, 250, 128)
        denoised_signal = denoise_signal(downsampled, 'sym20', 8, -5 , 5)

            
        # 1) Detect R-peaks
        r_peaks = r_peak_finder(denoised_signal)
        
        # 2) Compute HRV
        feats = compute_hrv_features(r_peaks, fs=128)
        # 3) Build CSV file name, e.g. "SCD_SubjectA_First_5_mins_before_SCD.csv"
        csv_filename = f"{segment_label}.csv"
        csv_path = os.path.join(output_dir_scd, csv_filename)
        # 4) Save
        save_hrv_to_csv(feats, csv_path)
# Out:
# Processing SCD subject 30...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_30_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_30_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_30_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_30_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_30_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_30_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 31...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_31_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_31_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_31_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_31_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_31_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_31_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 32...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_32_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_32_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_32_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_32_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_32_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_32_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 33...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_33_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_33_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_33_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_33_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_33_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_33_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 34...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_34_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_34_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_34_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_34_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_34_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_34_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 35...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_35_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_35_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_35_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_35_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_35_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_35_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 36...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_36_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_36_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_36_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_36_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_36_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_36_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 37...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_37_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_37_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_37_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_37_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_37_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_37_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 38...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_38_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_38_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_38_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_38_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_38_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_38_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 39...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_39_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_39_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_39_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_39_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_39_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_39_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 41...
#   -> Saved HRV features to SCD_Features_CSV_1h_10min_segments\SCD_41_First_10_mins_before_SCD.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 40
#      37 r_peaks = r_peak_finder(denoised_signal)
#      39 # 2) Compute HRV
# ---> 40 feats = compute_hrv_features(r_peaks, fs=128)
#      41 # 3) Build CSV file name, e.g. "SCD_SubjectA_First_5_mins_before_SCD.csv"
#      42 csv_filename = f"{segment_label}.csv"
#
# Cell In[17], line 27, in compute_hrv_features(r_peaks, fs)
#      25 mean_rr = np.mean(rr_ms)
#      26 sdrr = np.std(rr_ms, ddof=1) if len(rr_ms) > 1 else 0.0
# ---> 27 min_rr = np.min(rr_ms)
#      28 max_rr = np.max(rr_ms)
#      30 rr_diffs = np.diff(rr_ms)
#
# File ~\anaconda3\envs\notebook\Lib\site-packages\numpy\_core\fromnumeric.py:3042, in min(a, axis, out, keepdims, initial, where)
#    2925 @array_function_dispatch(_min_dispatcher)
#    2926 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2927         where=np._NoValue):
#    2928     """
#    2929     Return the minimum of an array or minimum along an axis.
#    2930
#    (...)
#    3040     6
#    3041     """
# -> 3042     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3043                           keepdims=keepdims, initial=initial, where=where)
#
# File ~\anaconda3\envs\notebook\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
f['41']
# Out:
# [[np.float64(0.030549060036687475),
#   np.float64(0.03470603464613811),
#   np.float64(0.03794421938381922),
#   np.float64(0.040151303043481947),
#   np.float64(0.04122402163748177),
#   np.float64(0.041070392856924),
#   np.float64(0.039610506632933785),
#   np.float64(0.03677694124331935),
#   np.float64(0.0325158997412975),
#   np.float64(0.026788166229532517),
#   np.float64(0.019569736720821462),
#   np.float64(0.0108525587532284),
#   np.float64(0.0006453065228445047),
#   np.float64(-0.011024316109324321),
#   np.float64(-0.02410479446947726),
#   np.float64(-0.03851528685560528),
#   np.float64(-0.05414067250086328),
#   np.float64(-0.07082805444231824),
#   np.float64(-0.08838590220329),
#   np.float64(-0.10658472906034974),
#   np.float64(-0.12515822333660415),
#   np.float64(-0.14380600848598638),
#   np.float64(-0.16219829359444726),
#   np.float64(-0.17998229853604952),
#   np.float64(-0.19679072172623513),
#   np.float64(-0.2122502479067813),
#   np.float64(-0.22598874578444572),
#   np.float64(-0.2376426720876531),
#   np.float64(-0.24686555352813844),
#   np.float64(-0.2533384189101661),
#   np.float64(-0.2567830414607572),
#   np.float64(-0.256975584916599),
#   np.float64(-0.253758407308744),
#   np.float64(-0.247050132016463),
#   np.float64(-0.2368532751800927),
#   np.float64(-0.22325944737166942),
#   np.float64(-0.20645260485523365),
#   np.float64(-0.18670796236873743),
#   np.float64(-0.1643852858849058),
#   np.float64(-0.1399181033690052),
#   np.float64(-0.11379987017187718),
#   np.float64(-0.08656937613836437),
#   np.float64(-0.05879747063927456),
#   np.float64(-0.03107321201138522),
#   np.float64(-0.003988020021505052),
#   np.float64(0.021881735310422465),
#   np.float64(0.04599383485059538),
#   np.float64(0.06785883966374191),
#   np.float64(0.087055910752394),
