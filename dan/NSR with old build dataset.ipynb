# %%
import wfdb
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.signal import medfilt
import pywt
from ecgdetectors import Detectors
from scipy.signal import resample_poly
import csv

# %%
nsr_data = ['./data/nsrdb/16265',
 './data/nsrdb/16272',
 './data/nsrdb/16273',
 './data/nsrdb/16420',
 './data/nsrdb/16483',
 './data/nsrdb/16539',
 './data/nsrdb/16773',
 './data/nsrdb/16786',
 './data/nsrdb/16795',
 './data/nsrdb/17052',
 './data/nsrdb/17453',
 './data/nsrdb/18177',
 './data/nsrdb/18184',
 './data/nsrdb/19088',
 './data/nsrdb/19090',
 './data/nsrdb/19093',
 './data/nsrdb/19140',
 './data/nsrdb/19830']

# %%
def extract_first_60min_and_segment(record_paths):
    """
    Given a list of NSR record paths (e.g. './data/nsrdb/16265'),
    1) Read the first 60 minutes of the ECG from each record
    2) Segment that 60-min signal into six 10-min parts
    3) Return a dictionary mapping record_name -> [segment1, segment2, ... segment6]
       Each segment is a NumPy array of shape (num_samples_5min, num_channels).
    """
    
    # For 60 min, we have 60 * 60 = 3600 seconds. 
    # For 10 min, we have 10 * 60 = 600 seconds.
    
    first_60min_segments = {}
    
    for record_path in record_paths:
        
        # Extract record name from path
        # e.g. record_path = "./data/nsrdb/16265" => record_name = "16265"
        record_dir, record_name = os.path.split(record_path)
      
        print(f"Processing {record_name} ...")
        
        # We want the first 60 minutes => 3600 seconds => num_samples = 3600 * fs
        fs = 128
        num_samples_60min = int(60 * 60 * fs)
        
        # Read from sample 0 to sample 0+num_samples_30min
        try:
            rec = wfdb.rdrecord(record_path, sampfrom=0, sampto=num_samples_60min)
        except Exception as e:
            print(f"[ERROR] Could not read {record_path}: {e}")
            continue
        
        if rec.p_signal is None:
            print(f"[WARN] No signal found in {record_name}. Skipping.")
            continue
        
        full_60min = rec.p_signal[:,0]
        
        # Segment the 60-min array into six 10-min parts
        # Each 10-min part = 10 * 60 * fs samples
        
        samples_10min = int(10 * 60 * fs)  # 600 seconds * 128 => 38400 * 2
        
        # We can slice in 6 equal blocks
        segments_10min = []
        for i in range(6):
            start_i = i * samples_10min
            end_i = start_i + samples_10min
            segment = full_60min[start_i:end_i]
            segments_10min.append(segment)
        
        # Store in a dictionary
        first_60min_segments[record_name] = segments_10min
        print(f"[OK] Extracted 6 segments of 10 min each from {record_name}.")
    
    return first_60min_segments

# %%
def denoise_signal(X, dwt_transform, dlevels, cutoff_low, cutoff_high):
    coeffs = pywt.wavedec(X, dwt_transform, level=dlevels)   # wavelet transform 'bior4.4'
    # scale 0 to cutoff_low 
    for ca in range(0,cutoff_low):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    # scale cutoff_high to end
    for ca in range(cutoff_high, len(coeffs)):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    Y = pywt.waverec(coeffs, dwt_transform) # inverse wavelet transform
    return Y

# %%
def r_peak_finder(ecg_sig):
    BASIC_SRATE = 128
    signal_pad_samples = 10
    signal_pad = np.zeros(signal_pad_samples)  # Pad to help detect early peaks
    scd_30_denoised_ = ...  # Your denoised 60-min ECG segment
    
    # Initialize the detectors at the given sampling rate
    detector_obj = Detectors(BASIC_SRATE)
    
    # Dictionary of detector functions
    detectors = {
        'pan_tompkins_detector': detector_obj.pan_tompkins_detector,
        'hamilton_detector': detector_obj.hamilton_detector,
        'christov_detector': detector_obj.christov_detector,
        'engzee_detector': detector_obj.engzee_detector,
        'swt_detector': detector_obj.swt_detector,
        'two_average_detector': detector_obj.two_average_detector,
    }
    
    r_peaks = np.array(detector_obj.engzee_detector(np.hstack((signal_pad, ecg_sig)) )) - signal_pad_samples
    return r_peaks

# %%
def compute_hrv_features(r_peaks, fs=128):
    """
    Time-domain HRV features from R-peaks.
    Returns a dict with:
      MeanRR, RMSDD, pNN50, SDRR, CVRR, NN50, MinRR, MaxRR
    """
    features = {
        'MeanRR': 0.0,
        'RMSDD': 0.0,
        'MADRR': 0.0,
        'MCVNN': 0.0,
        'pNN20': 0.0,
        'pNN50': 0.0,
        'SDRR': 0.0,
        'CVRR': 0.0,
        'NN20': 0,
        'NN50': 0,
        'MinRR': 0.0,
        'MaxRR': 0.0
    }

    rr_samples = np.diff(r_peaks)
    rr_ms = (rr_samples / fs) * 1000.0  # convert to ms

    mean_rr = np.mean(rr_ms)
    sdrr = np.std(rr_ms, ddof=1) if len(rr_ms) > 1 else 0.0
    min_rr = np.min(rr_ms)
    max_rr = np.max(rr_ms)

    rr_diffs = np.diff(rr_ms)
    rmssd = np.sqrt(np.mean(rr_diffs**2)) if len(rr_diffs) > 0 else 0.0
    nn50 = np.sum(np.abs(rr_diffs) > 50)
    pnn50 = (nn50 / len(rr_diffs)) * 100 if len(rr_diffs) > 0 else 0.0
    nn20 = np.sum(np.abs(rr_diffs) > 20)
    pnn20 = (nn20 / len(rr_diffs)) * 100 if len(rr_diffs) > 0 else 0.0
    cvrr = (sdrr / mean_rr * 100.0) if mean_rr else 0.0
    madrr = np.median(np.abs(rr_ms - np.median(rr_ms)))
    mcvnn = np.abs(rr_samples).mean()

    features['MeanRR'] = mean_rr / 1000.0
    features['RMSDD'] = rmssd / 1000.0
    # new 
    features['MADRR'] = madrr / 1000.0
    features['MCVNN'] = mcvnn / 1000.0 
    features['pNN20'] = pnn20 / 1000.0
    
    
    features['pNN50'] = pnn50 / 1000.0
    features['SDRR'] = sdrr / 1000.0
    features['CVRR'] = cvrr / 1000.0 
    # new
    features['NN20'] = nn20 / 1000.0
    
    features['NN50'] = nn50 / 1000.0
    features['MinRR'] = min_rr / 1000.0 
    features['MaxRR'] = max_rr / 1000.0
    
    return features

# %%
label_map = ["First", "Second", "Third", "Fourth", "Fifth", "Sixth"]

def save_hrv_to_csv(features_dict, csv_path):
    """
    Save a single row of features_dict into a CSV at csv_path.
    Overwrites if file exists.
    Columns: [MeanRR, RMSDD, MADRR, MCVNN, pNN20, pNN50, SDRR, CVRR, NN20, NN50, MinRR, MaxRR]
    """
    columns = ["MeanRR", "RMSDD", "MADRR", "MCVNN", "pNN20", "pNN50", "SDRR", "CVRR", "NN20", "NN50", "MinRR", "MaxRR"]
    with open(csv_path, mode='w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=columns)
        writer.writeheader()
        writer.writerow({col: features_dict[col] for col in columns})
    print(f"  -> Saved HRV features to {csv_path}")

# %%
nsr_segments  = extract_first_60min_and_segment(nsr_data)
# Out:
# Processing 16265 ...
# [OK] Extracted 6 segments of 10 min each from 16265.
# Processing 16272 ...
# [OK] Extracted 6 segments of 10 min each from 16272.
# Processing 16273 ...
# [OK] Extracted 6 segments of 10 min each from 16273.
# Processing 16420 ...
# [OK] Extracted 6 segments of 10 min each from 16420.
# Processing 16483 ...
# [OK] Extracted 6 segments of 10 min each from 16483.
# Processing 16539 ...
# [OK] Extracted 6 segments of 10 min each from 16539.
# Processing 16773 ...
# [OK] Extracted 6 segments of 10 min each from 16773.
# Processing 16786 ...
# [OK] Extracted 6 segments of 10 min each from 16786.
# Processing 16795 ...
# [OK] Extracted 6 segments of 10 min each from 16795.
# Processing 17052 ...
# [OK] Extracted 6 segments of 10 min each from 17052.
# Processing 17453 ...
# [OK] Extracted 6 segments of 10 min each from 17453.
# Processing 18177 ...
# [OK] Extracted 6 segments of 10 min each from 18177.
# Processing 18184 ...
# [OK] Extracted 6 segments of 10 min each from 18184.
# Processing 19088 ...
# [OK] Extracted 6 segments of 10 min each from 19088.
# Processing 19090 ...
# [OK] Extracted 6 segments of 10 min each from 19090.
# Processing 19093 ...
# [OK] Extracted 6 segments of 10 min each from 19093.
# Processing 19140 ...
# [OK] Extracted 6 segments of 10 min each from 19140.
# Processing 19830 ...
# [OK] Extracted 6 segments of 10 min each from 19830.

# %%
output_dir_nsr = "old_NSR_Features_CSV_1h_10min_segments"
os.makedirs(output_dir_nsr, exist_ok=True)

# %%
# Process NSR data (normal order => 1st is earliest 10 min)
for subj_id, seg_list in nsr_segments.items():
    print(f"\nProcessing NSR subject {subj_id}...")
    # seg_list[0] = first 10 min, seg_list[1] = second 10 min, ...
    for i in range(6):
        segment_label = f"NSR_{subj_id}_{label_map[i]}_10_min"  # e.g. "First_10_min"
        ecg_signal = seg_list[i]

        denoised_signal = denoise_signal(ecg_signal, 'rbio1.5', 9, 1 , 7)
        # 1) Detect R-peaks
        r_peaks = r_peak_finder(denoised_signal)
        # 2) Compute HRV
        feats = compute_hrv_features(r_peaks, fs=128)
        # 3) Build CSV file name, e.g. "NSR_SubjectX_First_10_min.csv"
        csv_filename = f"{segment_label}.csv"
        csv_path = os.path.join(output_dir_nsr, csv_filename)
        # 4) Save
        save_hrv_to_csv(feats, csv_path)
# Out:
# Processing NSR subject 16265...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16265_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16265_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16265_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16265_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16265_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16265_Sixth_10_min.csv
#
# Processing NSR subject 16272...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16272_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16272_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16272_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16272_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16272_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16272_Sixth_10_min.csv
#
# Processing NSR subject 16273...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16273_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16273_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16273_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16273_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16273_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16273_Sixth_10_min.csv
#
# Processing NSR subject 16420...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16420_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16420_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16420_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16420_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16420_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16420_Sixth_10_min.csv
#
# Processing NSR subject 16483...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16483_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16483_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16483_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16483_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16483_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16483_Sixth_10_min.csv
#
# Processing NSR subject 16539...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16539_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16539_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16539_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16539_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16539_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16539_Sixth_10_min.csv
#
# Processing NSR subject 16773...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16773_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16773_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16773_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16773_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16773_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16773_Sixth_10_min.csv
#
# Processing NSR subject 16786...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16786_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16786_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16786_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16786_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16786_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16786_Sixth_10_min.csv
#
# Processing NSR subject 16795...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16795_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16795_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16795_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16795_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16795_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_16795_Sixth_10_min.csv
#
# Processing NSR subject 17052...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17052_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17052_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17052_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17052_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17052_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17052_Sixth_10_min.csv
#
# Processing NSR subject 17453...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17453_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17453_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17453_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17453_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17453_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_17453_Sixth_10_min.csv
#
# Processing NSR subject 18177...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18177_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18177_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18177_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18177_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18177_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18177_Sixth_10_min.csv
#
# Processing NSR subject 18184...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18184_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18184_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18184_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18184_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18184_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_18184_Sixth_10_min.csv
#
# Processing NSR subject 19088...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19088_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19088_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19088_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19088_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19088_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19088_Sixth_10_min.csv
#
# Processing NSR subject 19090...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19090_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19090_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19090_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19090_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19090_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19090_Sixth_10_min.csv
#
# Processing NSR subject 19093...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19093_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19093_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19093_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19093_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19093_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19093_Sixth_10_min.csv
#
# Processing NSR subject 19140...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19140_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19140_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19140_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19140_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19140_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19140_Sixth_10_min.csv
#
# Processing NSR subject 19830...
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19830_First_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19830_Second_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19830_Third_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19830_Fourth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19830_Fifth_10_min.csv
#   -> Saved HRV features to old_NSR_Features_CSV_1h_10min_segments\NSR_19830_Sixth_10_min.csv
