# %%
import wfdb
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.signal import medfilt
import pywt
from ecgdetectors import Detectors
from scipy.signal import resample_poly
import csv

# %% [markdown]
# ## SCD db

# %%
scd_data = {
     './data/scddb/30': '07:54:33',
     './data/scddb/31': '13:42:24',
     './data/scddb/32': '16:45:18',
     './data/scddb/33': '04:46:19',
     './data/scddb/34': '06:35:44',
     './data/scddb/35': '24:34:56',
     './data/scddb/36': '18:59:01',
     './data/scddb/37': '01:31:13',
     './data/scddb/38': '08:01:54',
     './data/scddb/39': '04:37:51',
     #'./data/scddb/40': '00:00:00', # paced, no VF
     './data/scddb/41': '02:59:24', # not working properly
     #'./data/scddb/42': '00:00:00', # no VF
     './data/scddb/43': '15:37:11',
     './data/scddb/44': '19:38:45',
     './data/scddb/45': '18:09:17',
     './data/scddb/46': '03:41:47',
     './data/scddb/47': '06:13:01',
     './data/scddb/48': '02:29:40',
     #'./data/scddb/49': '00:00:00', # paced, no VF
     './data/scddb/50': '11:45:43',
     './data/scddb/51': '22:58:23',
     './data/scddb/52': '02:32:40' # not working properly
}

# %%
# H:M:S to seconds
def hms_to_seconds(hms):
    h, m, s = hms.split(':')
    return int(h)*3600 + int(m)*60 + int(s)

# %%
def extract_before_onset_VF(vfon_dict, minutes_before=60, fs=250):
    ecg_data_map = {} 

    for record_path, vf_onset_str in vfon_dict.items():
        # record_path might be '.data/scddb/30'
        record_dir, record_name = os.path.split(record_path)

        # 2) Convert dictionary's VF onset to seconds
        vf_onset_original_sec = hms_to_seconds(vf_onset_str)

        vfon_onset_original_sample = vf_onset_original_sec * fs

        seg_len_samples = int(minutes_before * 60 * fs)

        start_sample = vfon_onset_original_sample - seg_len_samples

         # read .dat between those sample indices
        try:
            #record_dat_path = os.path.join(record_dir, record_name)  # base path
            record_path_dat = os.path.join(record_dir, record_name)
            segment = wfdb.rdrecord(record_path_dat, sampfrom=start_sample, sampto=vfon_onset_original_sample)
            
        except Exception as e:
            print(f"[ERROR] Failed to read record {record_dat_path}: {e}")
            continue

        # Retrieve the raw signal data as a NumPy array
        if segment.p_signal is not None:
            arr = segment.p_signal[:,0]
            ecg_data_map[record_name] = arr
            print(f"[OK] Extracted 60-min for {record_name}: shape={arr.shape}")
        else:
            print(f"[WARNING] No p_signal found for {record_name}")

    return ecg_data_map

# %%
def segment_ecg(ecg_segment, segment_duration_sec=600, fs=250):
    samples_per_segment = segment_duration_sec * fs
    segments = np.array_split(ecg_segment, len(ecg_segment) // samples_per_segment)
    return segments

# %%
def resample_ecg(ecg_signal, orig_fs, target_fs):
    """
    Resample ECG signal from orig_fs to target_fs using polyphase filtering.
    ecg_signal: 1D (or 2D) numpy array (samples x channels)
    """
    # For example, if orig_fs=250, target_fs=128:
    # up = 128, down = 250
    up = target_fs
    down = orig_fs

    if ecg_signal.ndim == 1:
        ecg_resampled = resample_poly(ecg_signal, up, down)
    else:
        # If multi-channel, resample each column
        ecg_resampled = np.array([
            resample_poly(ecg_signal[:, ch], up, down) 
            for ch in range(ecg_signal.shape[1])
        ]).T

    return ecg_resampled

# %%
def denoise_signal(X, dwt_transform, dlevels, cutoff_low, cutoff_high):
    coeffs = pywt.wavedec(X, dwt_transform, level=dlevels)   # wavelet transform 'bior4.4'
    # scale 0 to cutoff_low 
    for ca in range(0,cutoff_low):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    # scale cutoff_high to end
    for ca in range(cutoff_high, len(coeffs)):
        coeffs[ca]=np.multiply(coeffs[ca],[0.0])
    Y = pywt.waverec(coeffs, dwt_transform) # inverse wavelet transform
    return Y

# %%
fs = 128
def get_median_filter_width(sampling_rate, duration):
    res = int( sampling_rate*duration )
    res += ((res%2) - 1) # needs to be an odd number
    return res

ms_flt_array = [0.2,0.6]    #<-- length of baseline fitting filters (in seconds)
mfa = np.zeros(len(ms_flt_array), dtype='int')
for i in range(0, len(ms_flt_array)):
    mfa[i] = get_median_filter_width(fs,ms_flt_array[i])

def filter_signal(X):
    global mfa
    X0 = X  #read orignal signal
    for mi in range(0,len(mfa)):
        X0 = medfilt(X0,mfa[mi]) # apply median filter one by one on top of each other
    X0 = np.subtract(X,X0)  # finally subtract from orignal signal
    return X0

# %%
def r_peak_finder(ecg_sig):
    BASIC_SRATE = 128
    signal_pad_samples = 10
    signal_pad = np.zeros(signal_pad_samples)  # Pad to help detect early peaks
    scd_30_denoised_ = ...  # Your denoised 30-min ECG segment
    
    # Initialize the detectors at the given sampling rate
    detector_obj = Detectors(BASIC_SRATE)
    
    # Dictionary of detector functions
    detectors = {
        'pan_tompkins_detector': detector_obj.pan_tompkins_detector,
        'hamilton_detector': detector_obj.hamilton_detector,
        'christov_detector': detector_obj.christov_detector,
        'engzee_detector': detector_obj.engzee_detector,
        'swt_detector': detector_obj.swt_detector,
        'two_average_detector': detector_obj.two_average_detector,
    }
    
    r_peaks = np.array(detector_obj.christov_detector(np.hstack((signal_pad, ecg_sig)) )) - signal_pad_samples
    return r_peaks

# %%
def compute_hrv_features(r_peaks, fs=128):
    """
    Time-domain HRV features from R-peaks.
    Returns a dict with:
      MeanRR, RMSDD, pNN50, SDRR, CVRR, NN50, MinRR, MaxRR
    """
    features = {
        'MeanRR': 0.0,
        'RMSDD': 0.0,
        'MADRR': 0.0,
        'MCVNN': 0.0,
        'pNN20': 0.0,
        'pNN50': 0.0,
        'SDRR': 0.0,
        'CVRR': 0.0,
        'NN20': 0,
        'NN50': 0,
        'MinRR': 0.0,
        'MaxRR': 0.0
    }

    rr_samples = np.diff(r_peaks)
    rr_ms = (rr_samples / fs) * 1000.0  # convert to ms

    mean_rr = np.mean(rr_ms)
    sdrr = np.std(rr_ms, ddof=1) if len(rr_ms) > 1 else 0.0
    min_rr = np.min(rr_ms)
    max_rr = np.max(rr_ms)

    rr_diffs = np.diff(rr_ms)
    rmssd = np.sqrt(np.mean(rr_diffs**2)) if len(rr_diffs) > 0 else 0.0
    nn50 = np.sum(np.abs(rr_diffs) > 50)
    pnn50 = (nn50 / len(rr_diffs)) * 100 if len(rr_diffs) > 0 else 0.0
    nn20 = np.sum(np.abs(rr_diffs) > 20)
    pnn20 = (nn20 / len(rr_diffs)) * 100 if len(rr_diffs) > 0 else 0.0
    cvrr = (sdrr / mean_rr * 100.0) if mean_rr else 0.0
    madrr = np.median(np.abs(rr_ms - np.median(rr_ms)))
    mcvnn = np.abs(rr_samples).mean()

    features['MeanRR'] = mean_rr / 1000.0
    features['RMSDD'] = rmssd / 1000.0
    # new 
    features['MADRR'] = madrr / 1000.0
    features['MCVNN'] = mcvnn / 1000.0 
    features['pNN20'] = pnn20 / 1000.0
    
    
    features['pNN50'] = pnn50 / 1000.0
    features['SDRR'] = sdrr / 1000.0
    features['CVRR'] = cvrr / 1000.0 
    # new
    features['NN20'] = nn20 / 1000.0
    
    features['NN50'] = nn50 / 1000.0
    features['MinRR'] = min_rr / 1000.0 
    features['MaxRR'] = max_rr / 1000.0
    
    return features

# %%
label_map = ["First", "Second", "Third", "Fourth", "Fifth", "Sixth"]

def save_hrv_to_csv(features_dict, csv_path):
    """
    Save a single row of features_dict into a CSV at csv_path.
    Overwrites if file exists.
    Columns: [MeanRR, RMSDD, MADRR, MCVNN, pNN20, pNN50, SDRR, CVRR, NN20, NN50, MinRR, MaxRR]
    """
    columns = ["MeanRR", "RMSDD", "MADRR", "MCVNN", "pNN20", "pNN50", "SDRR", "CVRR", "NN20", "NN50", "MinRR", "MaxRR"]
    with open(csv_path, mode='w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=columns)
        writer.writeheader()
        writer.writerow({col: features_dict[col] for col in columns})
    print(f"  -> Saved HRV features to {csv_path}")

# %%
onsetVF_60min_scd = extract_before_onset_VF(scd_data, minutes_before=60, fs=250)
# Out:
# [OK] Extracted 60-min for 30: shape=(900000,)
# [OK] Extracted 60-min for 31: shape=(900000,)
# [OK] Extracted 60-min for 32: shape=(900000,)
# [OK] Extracted 60-min for 33: shape=(900000,)
# [OK] Extracted 60-min for 34: shape=(900000,)
# [OK] Extracted 60-min for 35: shape=(900000,)
# [OK] Extracted 60-min for 36: shape=(900000,)
# [OK] Extracted 60-min for 37: shape=(900000,)
# [OK] Extracted 60-min for 38: shape=(900000,)
# [OK] Extracted 60-min for 39: shape=(900000,)
# [OK] Extracted 60-min for 41: shape=(900000,)
# [OK] Extracted 60-min for 43: shape=(900000,)
# [OK] Extracted 60-min for 44: shape=(900000,)
# [OK] Extracted 60-min for 45: shape=(900000,)
# [OK] Extracted 60-min for 46: shape=(900000,)
# [OK] Extracted 60-min for 47: shape=(900000,)
# [OK] Extracted 60-min for 48: shape=(900000,)
# [OK] Extracted 60-min for 50: shape=(900000,)
# [OK] Extracted 60-min for 51: shape=(900000,)
# [OK] Extracted 60-min for 52: shape=(900000,)

# %%
scd_segments = {}
for key, value in onsetVF_60min_scd.items():
    scd_segments[key] = segment_ecg(value)

# %%
scd_segments
# Out:
# {'30': [array([-0.2675 , -0.26625, -0.2625 , ...,  0.285  ,  0.395  ,  0.49875]),
#   array([ 0.61125,  0.665  ,  0.69875, ..., -0.10125, -0.0975 , -0.1    ]),
#   array([-0.1025 , -0.10375, -0.1025 , ...,  0.09125,  0.1    ,  0.10375]),
#   array([ 0.11   ,  0.11875,  0.13   , ..., -0.21625, -0.2175 , -0.22375]),
#   array([-0.2275 , -0.23125, -0.23625, ..., -0.005  ,  0.02   ,  0.0525 ]),
#   array([ 0.11375,  0.1975 ,  0.315  , ..., -0.03625, -0.03875, -0.0425 ])],
#  '31': [array([-0.07875, -0.07875, -0.075  , ...,  0.03   ,  0.035  ,  0.03375]),
#   array([0.03125, 0.02875, 0.0325 , ..., 0.00125, 0.00125, 0.005  ]),
#   array([0.015  , 0.0225 , 0.02   , ..., 0.0975 , 0.09875, 0.0925 ]),
#   array([ 0.0925 ,  0.095  ,  0.09375, ..., -0.42625, -0.43   , -0.43125]),
#   array([-0.44   , -0.43625, -0.43625, ..., -0.13375, -0.135  , -0.13625]),
#   array([-0.13625, -0.1325 , -0.1325 , ..., -0.10875, -0.105  , -0.10875])],
#  '32': [array([-0.09375, -0.1025 , -0.11   , ...,  0.03625,  0.04625,  0.05625]),
#   array([0.06125, 0.0625 , 0.06625, ..., 0.02375, 0.03625, 0.04125]),
#   array([ 0.03875,  0.02875,  0.025  , ..., -0.00125,  0.0125 ,  0.02375]),
#   array([ 0.04375,  0.0575 ,  0.06125, ..., -0.01   , -0.0075 , -0.00625]),
#   array([-0.005  , -0.0075 , -0.00875, ..., -0.03   , -0.0275 , -0.03125]),
#   array([-0.035  , -0.035  , -0.035  , ...,  0.19375,  0.16625,  0.14625])],
#  '33': [array([0.405  , 0.4175 , 0.41375, ..., 0.0625 , 0.06125, 0.0625 ]),
#   array([0.06   , 0.0575 , 0.055  , ..., 0.0525 , 0.04875, 0.04625]),
#   array([0.0475 , 0.0475 , 0.0475 , ..., 0.60375, 0.585  , 0.58625]),
#   array([ 0.57625,  0.5825 ,  0.5775 , ..., -0.14   , -0.14125, -0.14125]),
#   array([-0.14375, -0.135  , -0.11   , ...,  0.02125,  0.01375,  0.01   ]),
#   array([ 0.0075 ,  0.00625,  0.00375, ..., -0.18   , -0.18   , -0.18   ])],
#  '34': [array([ 0.1975 ,  0.2175 ,  0.235  , ..., -0.25125, -0.25125, -0.24375]),
#   array([-0.245  , -0.2425 , -0.24125, ..., -0.31125, -0.31   , -0.315  ]),
#   array([-0.31625, -0.32125, -0.3225 , ..., -0.2375 , -0.23875, -0.24   ]),
#   array([-0.2375 , -0.2375 , -0.23375, ..., -0.115  , -0.1125 , -0.11   ]),
#   array([-0.105  , -0.1    , -0.09125, ...,  0.22   ,  0.2175 ,  0.2175 ]),
#   array([0.21625, 0.22125, 0.21875, ..., 0.53   , 0.44625, 0.3775 ])],
#  '35': [array([-0.3725 , -0.3575 , -0.35375, ...,  0.215  ,  0.07875,  0.1425 ]),
#   array([ 0.31625,  0.36375,  0.17375, ..., -0.185  , -0.2    , -0.235  ]),
#   array([-0.26   , -0.26625, -0.26125, ..., -0.21625, -0.245  , -0.26125]),
#   array([-0.2625 , -0.25   , -0.2475 , ..., -0.0175 , -0.035  , -0.06375]),
#   array([-0.05875, -0.01   ,  0.0225 , ..., -0.32625, -0.33   , -0.325  ]),
#   array([-0.325  , -0.3275 , -0.32625, ..., -0.50375, -0.4975 , -0.4825 ])],
#  '36': [array([ 0.01   , -0.01   , -0.0175 , ..., -0.45625, -0.53375, -0.5225 ]),
#   array([-0.4875 , -0.4875 , -0.485  , ..., -0.06625, -0.0625 , -0.05375]),
#   array([-0.05   , -0.05875, -0.05   , ...,  0.0275 ,  0.01375,  0.035  ]),
#   array([0.09125, 0.13875, 0.21125, ..., 0.2025 , 0.27   , 0.31375]),
#   array([ 0.36375,  0.445  ,  0.5225 , ..., -0.18125, -0.16125, -0.145  ]),
#   array([-0.1325 , -0.125  , -0.12625, ...,  0.00875,  0.01625,  0.01   ])],
#  '37': [array([-0.14625, -0.1575 , -0.1725 , ..., -0.06   , -0.05875, -0.05875]),
#   array([-0.04625, -0.0175 ,  0.0075 , ..., -0.12875, -0.135  , -0.1325 ]),
#   array([-0.13125, -0.1325 , -0.1375 , ..., -0.03375, -0.03   , -0.0275 ]),
#   array([-0.02625, -0.02375, -0.02625, ...,  0.06125, -0.045  , -0.12   ]),
#   array([-0.16875, -0.19625, -0.21125, ...,  0.22875,  0.24875,  0.2475 ]),
#   array([0.25   , 0.27375, 0.325  , ..., 0.1075 , 0.11375, 0.12375])],
#  '38': [array([-0.07625, -0.07125, -0.0825 , ...,  0.19   ,  0.17   ,  0.15   ]),
#   array([ 0.1375 ,  0.115  ,  0.0875 , ...,  0.00125, -0.0025 , -0.00875]),
#   array([-0.015  , -0.01625, -0.02625, ..., -0.1775 , -0.225  , -0.29625]),
#   array([-0.37875, -0.46   , -0.5225 , ..., -0.175  , -0.11125, -0.05625]),
#   array([-0.01625,  0.0175 ,  0.05   , ...,  0.11625,  0.125  ,  0.1425 ]),
#   array([0.15375, 0.17125, 0.1825 , ..., 0.68375, 0.6575 , 0.64   ])],
#  '39': [array([ 1.23 ,  1.3  ,  1.32 , ..., -0.25 , -0.235, -0.225]),
#   array([-0.21 , -0.18 , -0.13 , ..., -0.23 , -0.225, -0.235]),
#   array([-0.265, -0.245, -0.205, ...,  0.055, -0.155, -0.375]),
#   array([-0.485, -0.45 , -0.445, ..., -0.505, -0.525, -0.54 ]),
#   array([-0.555, -0.53 , -0.465, ...,  1.435,  1.44 ,  1.42 ]),
#   array([1.325, 1.295, 1.255, ..., 0.11 , 0.06 , 0.035])],
#  '41': [array([-0.2925, -0.2275, -0.17  , ..., -0.04  , -0.0375, -0.035 ]),
#   array([-0.035  , -0.035  , -0.035  , ..., -0.18   , -0.18375, -0.18375]),
#   array([-0.1875 , -0.18875, -0.19375, ...,  0.175  ,  0.18   ,  0.18625]),
#   array([ 0.18375,  0.185  ,  0.19   , ..., -0.02   , -0.0225 , -0.025  ]),
#   array([-0.0275 , -0.03125, -0.0325 , ...,  0.04375,  0.045  ,  0.05   ]),
#   array([ 0.0475 ,  0.0425 ,  0.04875, ..., -0.01625,  0.     ,  0.0175 ])],
#  '43': [array([-0.17625, -0.17625, -0.1775 , ..., -0.04   , -0.04625, -0.05625]),
#   array([-0.06375, -0.06375, -0.06   , ...,  0.005  , -0.0075 , -0.01625]),
#   array([-0.02625, -0.035  , -0.04125, ..., -0.01125, -0.00875, -0.00625]),
#   array([-0.005  ,  0.     ,  0.0025 , ..., -0.32625, -0.32625, -0.33125]),
#   array([-0.33625, -0.3425 , -0.33875, ...,  0.05375,  0.05375,  0.0725 ]),
#   array([ 0.0925 ,  0.11375,  0.115  , ..., -0.005  , -0.005  , -0.00125])],
#  '44': [array([ 0.08875,  0.075  ,  0.05625, ..., -0.05625, -0.0525 , -0.05625]),
#   array([-0.0575 , -0.0575 , -0.055  , ..., -0.06625, -0.0625 , -0.06625]),
#   array([-0.0625 , -0.0625 , -0.065  , ..., -0.11625, -0.12875, -0.14   ]),
#   array([-0.145  , -0.1525 , -0.16375, ...,  0.16125,  0.03125, -0.03125]),
#   array([-0.0525 , -0.0625 , -0.07375, ..., -0.1    , -0.09125, -0.07875]),
#   array([-0.08125, -0.06875, -0.06   , ..., -0.63125, -0.62125, -0.5925 ])],
#  '45': [array([0.08875, 0.0875 , 0.09125, ..., 0.05375, 0.05875, 0.06   ]),
#   array([0.055  , 0.05375, 0.0525 , ..., 0.105  , 0.105  , 0.1025 ]),
#   array([ 0.0975 ,  0.09375,  0.09625, ..., -0.16   , -0.1575 , -0.1475 ]),
#   array([-0.15125, -0.155  , -0.15375, ...,  0.00375,  0.04875,  0.09125]),
#   array([ 0.08375,  0.04625,  0.0475 , ..., -0.08625, -0.09125, -0.09125]),
#   array([-0.0925 , -0.09125, -0.085  , ..., -0.465  , -0.4775 , -0.49   ])],
#  '46': [array([-0.01375, -0.0175 , -0.02625, ..., -0.02625, -0.0225 , -0.01875]),
#   array([-0.015  , -0.01375, -0.0175 , ...,  0.0075 ,  0.01   ,  0.01   ]),
#   array([0.00625, 0.00875, 0.00625, ..., 0.0575 , 0.07   , 0.08125]),
#   array([ 0.085  ,  0.09   ,  0.09125, ..., -0.04875, -0.055  , -0.06125]),
#   array([-0.0675 , -0.06625, -0.06375, ..., -0.22875, -0.245  , -0.2525 ]),
#   array([-0.24875, -0.23375, -0.21375, ..., -0.1525 , -0.3125 , -0.44125])],
#  '47': [array([-0.1  , -0.1  , -0.145, ...,  0.075,  0.075,  0.06 ]),
#   array([0.06, 0.07, 0.05, ..., 0.11, 0.29, 0.4 ]),
#   array([ 0.385,  0.23 , -0.035, ..., -1.155, -1.15 , -1.105]),
#   array([-1.05 , -0.98 , -0.975, ...,  0.165,  0.15 ,  0.15 ]),
#   array([ 0.16 ,  0.23 ,  0.305, ..., -0.29 , -0.285, -0.31 ]),
#   array([-0.36 , -0.385, -0.39 , ..., -0.63 , -0.625, -0.605])],
#  '48': [array([-0.24875, -0.27125, -0.29375, ...,  0.085  ,  0.05125,  0.0625 ]),
#   array([0.10125, 0.1225 , 0.13625, ..., 1.11875, 0.99375, 0.74125]),
#   array([ 0.45625,  0.2625 ,  0.17   , ..., -0.225  , -0.23375, -0.23625]),
#   array([-0.24   , -0.2475 , -0.25625, ..., -0.13375, -0.1425 , -0.1475 ]),
#   array([-0.14875, -0.145  , -0.14   , ..., -0.12875, -0.12   , -0.105  ]),
#   array([-0.08125, -0.04875, -0.02875, ..., -0.165  , -0.165  , -0.165  ])],
#  '50': [array([-0.1175 , -0.1275 , -0.13375, ...,  0.2425 ,  0.245  ,  0.25125]),
#   array([0.25125, 0.25375, 0.255  , ..., 0.04125, 0.04375, 0.0475 ]),
#   array([ 0.04875,  0.04875,  0.05   , ..., -0.13   , -0.13   , -0.13   ]),
#   array([-0.13125, -0.13625, -0.13875, ..., -0.31625, -0.30625, -0.30125]),
#   array([-0.2875 , -0.27625, -0.265  , ...,  0.16   ,  0.14625,  0.1375 ]),
#   array([0.12625, 0.12   , 0.115  , ..., 0.08875, 0.08   , 0.06875])],
#  '51': [array([-0.01   , -0.00875, -0.00875, ..., -0.005  , -0.00375, -0.01625]),
#   array([-0.10375, -0.23875, -0.04875, ...,  0.04875,  0.05625,  0.065  ]),
#   array([ 0.06625,  0.0925 ,  0.13875, ..., -0.33875, -0.31875, -0.3    ]),
#   array([-0.28875, -0.27875, -0.27625, ...,  0.26125,  0.2525 ,  0.25625]),
#   array([0.2575 , 0.27125, 0.28625, ..., 0.005  , 0.00375, 0.01125]),
#   array([ 0.01   ,  0.01   ,  0.00875, ..., -1.32375, -1.335  , -1.365  ])],
#  '52': [array([ 0.125  ,  0.14   ,  0.13   , ..., -0.25   , -0.23875, -0.23875]),
#   array([-0.24   , -0.24625, -0.2425 , ..., -0.08625, -0.1075 , -0.11375]),
#   array([-0.1125 , -0.1125 , -0.1075 , ..., -0.82375, -0.8075 , -0.8075 ]),
#   array([-0.79   , -0.79   , -0.78375, ...,  0.29625,  0.2575 ,  0.26625]),
#   array([ 0.31125,  0.33625,  0.385  , ..., -0.24   , -0.23875, -0.2475 ]),
#   array([-0.26125, -0.27375, -0.2775 , ...,  1.53625,  1.18125,  0.75   ])]}

# %%
output_dir_scd = "SCD_Features_CSV_1h10min_segments"
os.makedirs(output_dir_scd, exist_ok=True)

# %%
for subj_id, seg_list in scd_segments.items():
    print(f"\nProcessing SCD subject {subj_id}...")
    # seg_list[0] = earliest, seg_list[5] = last
    # We want to label them in REVERSE order:
    #   i=0 => seg_list[5], name: "First 5 mins before SCD"
    #   i=1 => seg_list[4], name: "Second 5 mins before SCD"
    #   ...
    #   i=5 => seg_list[0], name: "Sixth 5 mins before SCD"
    for i in range(6):
        segment_idx = 5 - i  # reversed index
        segment_label = f"SCD_{subj_id}_{label_map[i]}_10_mins_before_SCD"  # e.g. "First_5_mins_before_SCD"
        ecg_signal = seg_list[segment_idx]


        downsampled = resample_ecg(ecg_signal, 250, 128)
        baseline_eliminate = filter_signal(downsampled)

        if subj_id in ['35', '41', '52']:
            print("INSIDE THE if subj_id in ['35', '41', '52']:")
            # Range bounds as float64
            low = np.float64(-0.9525)
            high = np.float64(1.05875)
            
            arr = baseline_eliminate
            nan_mask = np.isnan(arr)
            num_nans = np.sum(nan_mask)
            if num_nans > 0:
                # Generate random float64 numbers
                random_values = np.random.uniform(low, high, size=num_nans).astype(np.float64)
                # Replace NaNs
                arr[nan_mask] = random_values
                baseline_eliminate = arr  # Save back to dict
                
        denoised_signal = denoise_signal(baseline_eliminate, 'bior4.4', 9 , 1 , 7)

            
        # 1) Detect R-peaks
        r_peaks = r_peak_finder(denoised_signal)
        
        # 2) Compute HRV
        feats = compute_hrv_features(r_peaks, fs=128)
        # 3) Build CSV file name, e.g. "SCD_SubjectA_First_5_mins_before_SCD.csv"
        csv_filename = f"{segment_label}.csv"
        csv_path = os.path.join(output_dir_scd, csv_filename)
        # 4) Save
        save_hrv_to_csv(feats, csv_path)
# Out:
# Processing SCD subject 30...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_30_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_30_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_30_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_30_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_30_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_30_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 31...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_31_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_31_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_31_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_31_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_31_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_31_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 32...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_32_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_32_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_32_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_32_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_32_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_32_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 33...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_33_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_33_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_33_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_33_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_33_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_33_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 34...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_34_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_34_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_34_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_34_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_34_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_34_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 35...
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_35_First_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_35_Second_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_35_Third_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_35_Fourth_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_35_Fifth_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_35_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 36...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_36_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_36_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_36_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_36_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_36_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_36_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 37...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_37_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_37_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_37_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_37_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_37_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_37_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 38...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_38_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_38_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_38_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_38_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_38_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_38_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 39...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_39_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_39_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_39_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_39_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_39_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_39_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 41...
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_41_First_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_41_Second_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_41_Third_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_41_Fourth_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_41_Fifth_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_41_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 43...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_43_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_43_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_43_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_43_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_43_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_43_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 44...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_44_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_44_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_44_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_44_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_44_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_44_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 45...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_45_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_45_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_45_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_45_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_45_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_45_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 46...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_46_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_46_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_46_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_46_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_46_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_46_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 47...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_47_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_47_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_47_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_47_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_47_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_47_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 48...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_48_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_48_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_48_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_48_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_48_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_48_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 50...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_50_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_50_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_50_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_50_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_50_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_50_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 51...
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_51_First_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_51_Second_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_51_Third_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_51_Fourth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_51_Fifth_10_mins_before_SCD.csv
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_51_Sixth_10_mins_before_SCD.csv
#
# Processing SCD subject 52...
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_52_First_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_52_Second_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_52_Third_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_52_Fourth_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_52_Fifth_10_mins_before_SCD.csv
# INSIDE THE if subj_id in ['35', '41', '52']:
#   -> Saved HRV features to SCD_Features_CSV_1h10min_segments\SCD_52_Sixth_10_mins_before_SCD.csv
